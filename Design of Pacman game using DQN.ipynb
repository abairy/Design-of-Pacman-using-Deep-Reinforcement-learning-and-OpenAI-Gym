# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# !pip install gym
import numpy as np
np.random.seed(123)
print("NumPy:{}".format(np.__version__))

import tensorflow as tf
tf.set_random_seed(123)
print("TensorFlow:{}".format(tf.__version__))

import tensorflow.keras as keras
print("Keras:{}".format(keras.__version__))

import gym
print('OpenAI Gym:',gym.__version__)
# Out:
# Collecting gym
#   Downloading https://files.pythonhosted.org/packages/c7/98/fad8b85827d9aca922eec6a8747dd696aac281ebdc4b1225acf51f8f612f/gym-0.12.0.tar.gz (1.5MB)
# Requirement already satisfied: scipy in c:\users\13154\anaconda3\lib\site-packages (from gym) (1.1.0)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\13154\anaconda3\lib\site-packages (from gym) (1.15.4)
# Requirement already satisfied: requests>=2.0 in c:\users\13154\anaconda3\lib\site-packages (from gym) (2.20.1)
# Requirement already satisfied: six in c:\users\13154\anaconda3\lib\site-packages (from gym) (1.11.0)
# Collecting pyglet>=1.2.0 (from gym)
#   Downloading https://files.pythonhosted.org/packages/1c/fc/dad5eaaab68f0c21e2f906a94ddb98175662cc5a654eee404d59554ce0fa/pyglet-1.3.2-py2.py3-none-any.whl (1.0MB)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\13154\anaconda3\lib\site-packages (from requests>=2.0->gym) (2.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\13154\anaconda3\lib\site-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\13154\anaconda3\lib\site-packages (from requests>=2.0->gym) (2018.10.15)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\13154\anaconda3\lib\site-packages (from requests>=2.0->gym) (1.23)
# Collecting future (from pyglet>=1.2.0->gym)
#   Downloading https://files.pythonhosted.org/packages/90/52/e20466b85000a181e1e144fd8305caf2cf475e2f9674e797b222f8105f5f/future-0.17.1.tar.gz (829kB)
# Building wheels for collected packages: gym, future
#   Running setup.py bdist_wheel for gym: started
#   Running setup.py bdist_wheel for gym: finished with status 'done'
#   Stored in directory: C:\Users\13154\AppData\Local\pip\Cache\wheels\bf\b9\fd\e1f54a4b99eca10de0d37cc7ecc2ac29a2e51b4eff7e1e5ca7
#   Running setup.py bdist_wheel for future: started
#   Running setup.py bdist_wheel for future: finished with status 'done'
#   Stored in directory: C:\Users\13154\AppData\Local\pip\Cache\wheels\0c\61\d2\d6b7317325828fbb39ee6ad559dbe4664d0896da4721bf379e
# Successfully built gym future
# Installing collected packages: future, pyglet, gym
# Successfully installed future-0.17.1 gym-0.12.0 pyglet-1.3.2
# NumPy:1.15.4
# TensorFlow:1.12.0
# Keras:2.1.6-tf
# OpenAI Gym: 0.12.0

# %%
all_env = list(gym.envs.registry.all())
print('Total Environments in Gym version {} : {}'
    .format(gym.__version__,len(all_env)))
# Out:
# Total Environments in Gym version 0.12.0 : 821

# %%
for e in list(all_env):
    print(e)
# Out:
# EnvSpec(Copy-v0)
# EnvSpec(RepeatCopy-v0)
# EnvSpec(ReversedAddition-v0)
# EnvSpec(ReversedAddition3-v0)
# EnvSpec(DuplicatedInput-v0)
# EnvSpec(Reverse-v0)
# EnvSpec(CartPole-v0)
# EnvSpec(CartPole-v1)
# EnvSpec(MountainCar-v0)
# EnvSpec(MountainCarContinuous-v0)
# EnvSpec(Pendulum-v0)
# EnvSpec(Acrobot-v1)
# EnvSpec(LunarLander-v2)
# EnvSpec(LunarLanderContinuous-v2)
# EnvSpec(BipedalWalker-v2)
# EnvSpec(BipedalWalkerHardcore-v2)
# EnvSpec(CarRacing-v0)
# EnvSpec(Blackjack-v0)
# EnvSpec(KellyCoinflip-v0)
# EnvSpec(KellyCoinflipGeneralized-v0)
# EnvSpec(FrozenLake-v0)
# EnvSpec(FrozenLake8x8-v0)
# EnvSpec(CliffWalking-v0)
# EnvSpec(NChain-v0)
# EnvSpec(Roulette-v0)
# EnvSpec(Taxi-v2)
# EnvSpec(GuessingGame-v0)
# EnvSpec(HotterColder-v0)
# EnvSpec(Reacher-v2)
# EnvSpec(Pusher-v2)
# EnvSpec(Thrower-v2)
# EnvSpec(Striker-v2)
# EnvSpec(InvertedPendulum-v2)
# EnvSpec(InvertedDoublePendulum-v2)
# EnvSpec(HalfCheetah-v2)
# EnvSpec(HalfCheetah-v3)
# EnvSpec(Hopper-v2)
# EnvSpec(Hopper-v3)
# EnvSpec(Swimmer-v2)
# EnvSpec(Swimmer-v3)
# EnvSpec(Walker2d-v2)
# EnvSpec(Walker2d-v3)
# EnvSpec(Ant-v2)
# EnvSpec(Ant-v3)
# EnvSpec(Humanoid-v2)
# EnvSpec(Humanoid-v3)
# EnvSpec(HumanoidStandup-v2)
# EnvSpec(FetchSlide-v1)
# EnvSpec(FetchPickAndPlace-v1)
# EnvSpec(FetchReach-v1)
# EnvSpec(FetchPush-v1)
# EnvSpec(HandReach-v0)
# EnvSpec(HandManipulateBlockRotateZ-v0)
# EnvSpec(HandManipulateBlockRotateParallel-v0)
# EnvSpec(HandManipulateBlockRotateXYZ-v0)
# EnvSpec(HandManipulateBlockFull-v0)
# EnvSpec(HandManipulateBlock-v0)
# EnvSpec(HandManipulateBlockTouchSensors-v0)
# EnvSpec(HandManipulateEggRotate-v0)
# EnvSpec(HandManipulateEggFull-v0)
# EnvSpec(HandManipulateEgg-v0)
# EnvSpec(HandManipulateEggTouchSensors-v0)
# EnvSpec(HandManipulatePenRotate-v0)
# EnvSpec(HandManipulatePenFull-v0)
# EnvSpec(HandManipulatePen-v0)
# EnvSpec(HandManipulatePenTouchSensors-v0)
# EnvSpec(FetchSlideDense-v1)
# EnvSpec(FetchPickAndPlaceDense-v1)
# EnvSpec(FetchReachDense-v1)
# EnvSpec(FetchPushDense-v1)
# EnvSpec(HandReachDense-v0)
# EnvSpec(HandManipulateBlockRotateZDense-v0)
# EnvSpec(HandManipulateBlockRotateParallelDense-v0)
# EnvSpec(HandManipulateBlockRotateXYZDense-v0)
# EnvSpec(HandManipulateBlockFullDense-v0)
# EnvSpec(HandManipulateBlockDense-v0)
# EnvSpec(HandManipulateBlockTouchSensorsDense-v0)
# EnvSpec(HandManipulateEggRotateDense-v0)
# EnvSpec(HandManipulateEggFullDense-v0)
# EnvSpec(HandManipulateEggDense-v0)
# EnvSpec(HandManipulateEggTouchSensorsDense-v0)
# EnvSpec(HandManipulatePenRotateDense-v0)
# EnvSpec(HandManipulatePenFullDense-v0)
# EnvSpec(HandManipulatePenDense-v0)
# EnvSpec(HandManipulatePenTouchSensorsDense-v0)
# EnvSpec(AirRaid-v0)
# EnvSpec(AirRaid-v4)
# EnvSpec(AirRaidDeterministic-v0)
# EnvSpec(AirRaidDeterministic-v4)
# EnvSpec(AirRaidNoFrameskip-v0)
# EnvSpec(AirRaidNoFrameskip-v4)
# EnvSpec(AirRaid-ram-v0)
# EnvSpec(AirRaid-ram-v4)
# EnvSpec(AirRaid-ramDeterministic-v0)
# EnvSpec(AirRaid-ramDeterministic-v4)
# EnvSpec(AirRaid-ramNoFrameskip-v0)
# EnvSpec(AirRaid-ramNoFrameskip-v4)
# EnvSpec(Alien-v0)
# EnvSpec(Alien-v4)
# EnvSpec(AlienDeterministic-v0)
# EnvSpec(AlienDeterministic-v4)
# EnvSpec(AlienNoFrameskip-v0)
# EnvSpec(AlienNoFrameskip-v4)
# EnvSpec(Alien-ram-v0)
# EnvSpec(Alien-ram-v4)
# EnvSpec(Alien-ramDeterministic-v0)
# EnvSpec(Alien-ramDeterministic-v4)
# EnvSpec(Alien-ramNoFrameskip-v0)
# EnvSpec(Alien-ramNoFrameskip-v4)
# EnvSpec(Amidar-v0)
# EnvSpec(Amidar-v4)
# EnvSpec(AmidarDeterministic-v0)
# EnvSpec(AmidarDeterministic-v4)
# EnvSpec(AmidarNoFrameskip-v0)
# EnvSpec(AmidarNoFrameskip-v4)
# EnvSpec(Amidar-ram-v0)
# EnvSpec(Amidar-ram-v4)
# EnvSpec(Amidar-ramDeterministic-v0)
# EnvSpec(Amidar-ramDeterministic-v4)
# EnvSpec(Amidar-ramNoFrameskip-v0)
# EnvSpec(Amidar-ramNoFrameskip-v4)
# EnvSpec(Assault-v0)
# EnvSpec(Assault-v4)
# EnvSpec(AssaultDeterministic-v0)
# EnvSpec(AssaultDeterministic-v4)
# EnvSpec(AssaultNoFrameskip-v0)
# EnvSpec(AssaultNoFrameskip-v4)
# EnvSpec(Assault-ram-v0)
# EnvSpec(Assault-ram-v4)
# EnvSpec(Assault-ramDeterministic-v0)
# EnvSpec(Assault-ramDeterministic-v4)
# EnvSpec(Assault-ramNoFrameskip-v0)
# EnvSpec(Assault-ramNoFrameskip-v4)
# EnvSpec(Asterix-v0)
# EnvSpec(Asterix-v4)
# EnvSpec(AsterixDeterministic-v0)
# EnvSpec(AsterixDeterministic-v4)
# EnvSpec(AsterixNoFrameskip-v0)
# EnvSpec(AsterixNoFrameskip-v4)
# EnvSpec(Asterix-ram-v0)
# EnvSpec(Asterix-ram-v4)
# EnvSpec(Asterix-ramDeterministic-v0)
# EnvSpec(Asterix-ramDeterministic-v4)
# EnvSpec(Asterix-ramNoFrameskip-v0)
# EnvSpec(Asterix-ramNoFrameskip-v4)
# EnvSpec(Asteroids-v0)
# EnvSpec(Asteroids-v4)
# EnvSpec(AsteroidsDeterministic-v0)
# EnvSpec(AsteroidsDeterministic-v4)
# EnvSpec(AsteroidsNoFrameskip-v0)
# EnvSpec(AsteroidsNoFrameskip-v4)
# EnvSpec(Asteroids-ram-v0)
# EnvSpec(Asteroids-ram-v4)
# EnvSpec(Asteroids-ramDeterministic-v0)
# EnvSpec(Asteroids-ramDeterministic-v4)
# EnvSpec(Asteroids-ramNoFrameskip-v0)
# EnvSpec(Asteroids-ramNoFrameskip-v4)
# EnvSpec(Atlantis-v0)
# EnvSpec(Atlantis-v4)
# EnvSpec(AtlantisDeterministic-v0)
# EnvSpec(AtlantisDeterministic-v4)
# EnvSpec(AtlantisNoFrameskip-v0)
# EnvSpec(AtlantisNoFrameskip-v4)
# EnvSpec(Atlantis-ram-v0)
# EnvSpec(Atlantis-ram-v4)
# EnvSpec(Atlantis-ramDeterministic-v0)
# EnvSpec(Atlantis-ramDeterministic-v4)
# EnvSpec(Atlantis-ramNoFrameskip-v0)
# EnvSpec(Atlantis-ramNoFrameskip-v4)
# EnvSpec(BankHeist-v0)
# EnvSpec(BankHeist-v4)
# EnvSpec(BankHeistDeterministic-v0)
# EnvSpec(BankHeistDeterministic-v4)
# EnvSpec(BankHeistNoFrameskip-v0)
# EnvSpec(BankHeistNoFrameskip-v4)
# EnvSpec(BankHeist-ram-v0)
# EnvSpec(BankHeist-ram-v4)
# EnvSpec(BankHeist-ramDeterministic-v0)
# EnvSpec(BankHeist-ramDeterministic-v4)
# EnvSpec(BankHeist-ramNoFrameskip-v0)
# EnvSpec(BankHeist-ramNoFrameskip-v4)
# EnvSpec(BattleZone-v0)
# EnvSpec(BattleZone-v4)
# EnvSpec(BattleZoneDeterministic-v0)
# EnvSpec(BattleZoneDeterministic-v4)
# EnvSpec(BattleZoneNoFrameskip-v0)
# EnvSpec(BattleZoneNoFrameskip-v4)
# EnvSpec(BattleZone-ram-v0)
# EnvSpec(BattleZone-ram-v4)
# EnvSpec(BattleZone-ramDeterministic-v0)
# EnvSpec(BattleZone-ramDeterministic-v4)
# EnvSpec(BattleZone-ramNoFrameskip-v0)
# EnvSpec(BattleZone-ramNoFrameskip-v4)
# EnvSpec(BeamRider-v0)
# EnvSpec(BeamRider-v4)
# EnvSpec(BeamRiderDeterministic-v0)
# EnvSpec(BeamRiderDeterministic-v4)
# EnvSpec(BeamRiderNoFrameskip-v0)
# EnvSpec(BeamRiderNoFrameskip-v4)
# EnvSpec(BeamRider-ram-v0)
# EnvSpec(BeamRider-ram-v4)
# EnvSpec(BeamRider-ramDeterministic-v0)
# EnvSpec(BeamRider-ramDeterministic-v4)
# EnvSpec(BeamRider-ramNoFrameskip-v0)
# EnvSpec(BeamRider-ramNoFrameskip-v4)
# EnvSpec(Berzerk-v0)
# EnvSpec(Berzerk-v4)
# EnvSpec(BerzerkDeterministic-v0)
# EnvSpec(BerzerkDeterministic-v4)
# EnvSpec(BerzerkNoFrameskip-v0)
# EnvSpec(BerzerkNoFrameskip-v4)
# EnvSpec(Berzerk-ram-v0)
# EnvSpec(Berzerk-ram-v4)
# EnvSpec(Berzerk-ramDeterministic-v0)
# EnvSpec(Berzerk-ramDeterministic-v4)
# EnvSpec(Berzerk-ramNoFrameskip-v0)
# EnvSpec(Berzerk-ramNoFrameskip-v4)
# EnvSpec(Bowling-v0)
# EnvSpec(Bowling-v4)
# EnvSpec(BowlingDeterministic-v0)
# EnvSpec(BowlingDeterministic-v4)
# EnvSpec(BowlingNoFrameskip-v0)
# EnvSpec(BowlingNoFrameskip-v4)
# EnvSpec(Bowling-ram-v0)
# EnvSpec(Bowling-ram-v4)
# EnvSpec(Bowling-ramDeterministic-v0)
# EnvSpec(Bowling-ramDeterministic-v4)
# EnvSpec(Bowling-ramNoFrameskip-v0)
# EnvSpec(Bowling-ramNoFrameskip-v4)
# EnvSpec(Boxing-v0)
# EnvSpec(Boxing-v4)
# EnvSpec(BoxingDeterministic-v0)
# EnvSpec(BoxingDeterministic-v4)
# EnvSpec(BoxingNoFrameskip-v0)
# EnvSpec(BoxingNoFrameskip-v4)
# EnvSpec(Boxing-ram-v0)
# EnvSpec(Boxing-ram-v4)
# EnvSpec(Boxing-ramDeterministic-v0)
# EnvSpec(Boxing-ramDeterministic-v4)
# EnvSpec(Boxing-ramNoFrameskip-v0)
# EnvSpec(Boxing-ramNoFrameskip-v4)
# EnvSpec(Breakout-v0)
# EnvSpec(Breakout-v4)
# EnvSpec(BreakoutDeterministic-v0)
# EnvSpec(BreakoutDeterministic-v4)
# EnvSpec(BreakoutNoFrameskip-v0)
# EnvSpec(BreakoutNoFrameskip-v4)
# EnvSpec(Breakout-ram-v0)
# EnvSpec(Breakout-ram-v4)
# EnvSpec(Breakout-ramDeterministic-v0)
# EnvSpec(Breakout-ramDeterministic-v4)
# EnvSpec(Breakout-ramNoFrameskip-v0)
# EnvSpec(Breakout-ramNoFrameskip-v4)
# EnvSpec(Carnival-v0)
# EnvSpec(Carnival-v4)
# EnvSpec(CarnivalDeterministic-v0)
# EnvSpec(CarnivalDeterministic-v4)
# EnvSpec(CarnivalNoFrameskip-v0)
# EnvSpec(CarnivalNoFrameskip-v4)
# EnvSpec(Carnival-ram-v0)
# EnvSpec(Carnival-ram-v4)
# EnvSpec(Carnival-ramDeterministic-v0)
# EnvSpec(Carnival-ramDeterministic-v4)
# EnvSpec(Carnival-ramNoFrameskip-v0)
# EnvSpec(Carnival-ramNoFrameskip-v4)
# EnvSpec(Centipede-v0)
# EnvSpec(Centipede-v4)
# EnvSpec(CentipedeDeterministic-v0)
# EnvSpec(CentipedeDeterministic-v4)
# EnvSpec(CentipedeNoFrameskip-v0)
# EnvSpec(CentipedeNoFrameskip-v4)
# EnvSpec(Centipede-ram-v0)
# EnvSpec(Centipede-ram-v4)
# EnvSpec(Centipede-ramDeterministic-v0)
# EnvSpec(Centipede-ramDeterministic-v4)
# EnvSpec(Centipede-ramNoFrameskip-v0)
# EnvSpec(Centipede-ramNoFrameskip-v4)
# EnvSpec(ChopperCommand-v0)
# EnvSpec(ChopperCommand-v4)
# EnvSpec(ChopperCommandDeterministic-v0)
# EnvSpec(ChopperCommandDeterministic-v4)
# EnvSpec(ChopperCommandNoFrameskip-v0)
# EnvSpec(ChopperCommandNoFrameskip-v4)
# EnvSpec(ChopperCommand-ram-v0)
# EnvSpec(ChopperCommand-ram-v4)
# EnvSpec(ChopperCommand-ramDeterministic-v0)
# EnvSpec(ChopperCommand-ramDeterministic-v4)
# EnvSpec(ChopperCommand-ramNoFrameskip-v0)
# EnvSpec(ChopperCommand-ramNoFrameskip-v4)
# EnvSpec(CrazyClimber-v0)
# EnvSpec(CrazyClimber-v4)
# EnvSpec(CrazyClimberDeterministic-v0)
# EnvSpec(CrazyClimberDeterministic-v4)
# EnvSpec(CrazyClimberNoFrameskip-v0)
# EnvSpec(CrazyClimberNoFrameskip-v4)
# EnvSpec(CrazyClimber-ram-v0)
# EnvSpec(CrazyClimber-ram-v4)
# EnvSpec(CrazyClimber-ramDeterministic-v0)
# EnvSpec(CrazyClimber-ramDeterministic-v4)
# EnvSpec(CrazyClimber-ramNoFrameskip-v0)
# EnvSpec(CrazyClimber-ramNoFrameskip-v4)
# EnvSpec(Defender-v0)
# EnvSpec(Defender-v4)
# EnvSpec(DefenderDeterministic-v0)
# EnvSpec(DefenderDeterministic-v4)
# EnvSpec(DefenderNoFrameskip-v0)
# EnvSpec(DefenderNoFrameskip-v4)
# EnvSpec(Defender-ram-v0)
# EnvSpec(Defender-ram-v4)
# EnvSpec(Defender-ramDeterministic-v0)
# EnvSpec(Defender-ramDeterministic-v4)
# EnvSpec(Defender-ramNoFrameskip-v0)
# EnvSpec(Defender-ramNoFrameskip-v4)
# EnvSpec(DemonAttack-v0)
# EnvSpec(DemonAttack-v4)
# EnvSpec(DemonAttackDeterministic-v0)
# EnvSpec(DemonAttackDeterministic-v4)
# EnvSpec(DemonAttackNoFrameskip-v0)
# EnvSpec(DemonAttackNoFrameskip-v4)
# EnvSpec(DemonAttack-ram-v0)
# EnvSpec(DemonAttack-ram-v4)
# EnvSpec(DemonAttack-ramDeterministic-v0)
# EnvSpec(DemonAttack-ramDeterministic-v4)
# EnvSpec(DemonAttack-ramNoFrameskip-v0)
# EnvSpec(DemonAttack-ramNoFrameskip-v4)
# EnvSpec(DoubleDunk-v0)
# EnvSpec(DoubleDunk-v4)
# EnvSpec(DoubleDunkDeterministic-v0)
# EnvSpec(DoubleDunkDeterministic-v4)
# EnvSpec(DoubleDunkNoFrameskip-v0)
# EnvSpec(DoubleDunkNoFrameskip-v4)
# EnvSpec(DoubleDunk-ram-v0)
# EnvSpec(DoubleDunk-ram-v4)
# EnvSpec(DoubleDunk-ramDeterministic-v0)
# EnvSpec(DoubleDunk-ramDeterministic-v4)
# EnvSpec(DoubleDunk-ramNoFrameskip-v0)
# EnvSpec(DoubleDunk-ramNoFrameskip-v4)
# EnvSpec(ElevatorAction-v0)
# EnvSpec(ElevatorAction-v4)
# EnvSpec(ElevatorActionDeterministic-v0)
# EnvSpec(ElevatorActionDeterministic-v4)
# EnvSpec(ElevatorActionNoFrameskip-v0)
# EnvSpec(ElevatorActionNoFrameskip-v4)
# EnvSpec(ElevatorAction-ram-v0)
# EnvSpec(ElevatorAction-ram-v4)
# EnvSpec(ElevatorAction-ramDeterministic-v0)
# EnvSpec(ElevatorAction-ramDeterministic-v4)
# EnvSpec(ElevatorAction-ramNoFrameskip-v0)
# EnvSpec(ElevatorAction-ramNoFrameskip-v4)
# EnvSpec(Enduro-v0)
# EnvSpec(Enduro-v4)
# EnvSpec(EnduroDeterministic-v0)
# EnvSpec(EnduroDeterministic-v4)
# EnvSpec(EnduroNoFrameskip-v0)
# EnvSpec(EnduroNoFrameskip-v4)
# EnvSpec(Enduro-ram-v0)
# EnvSpec(Enduro-ram-v4)
# EnvSpec(Enduro-ramDeterministic-v0)
# EnvSpec(Enduro-ramDeterministic-v4)
# EnvSpec(Enduro-ramNoFrameskip-v0)
# EnvSpec(Enduro-ramNoFrameskip-v4)
# EnvSpec(FishingDerby-v0)
# EnvSpec(FishingDerby-v4)
# EnvSpec(FishingDerbyDeterministic-v0)
# EnvSpec(FishingDerbyDeterministic-v4)
# EnvSpec(FishingDerbyNoFrameskip-v0)
# EnvSpec(FishingDerbyNoFrameskip-v4)
# EnvSpec(FishingDerby-ram-v0)
# EnvSpec(FishingDerby-ram-v4)
# EnvSpec(FishingDerby-ramDeterministic-v0)
# EnvSpec(FishingDerby-ramDeterministic-v4)
# EnvSpec(FishingDerby-ramNoFrameskip-v0)
# EnvSpec(FishingDerby-ramNoFrameskip-v4)
# EnvSpec(Freeway-v0)
# EnvSpec(Freeway-v4)
# EnvSpec(FreewayDeterministic-v0)
# EnvSpec(FreewayDeterministic-v4)
# EnvSpec(FreewayNoFrameskip-v0)
# EnvSpec(FreewayNoFrameskip-v4)
# EnvSpec(Freeway-ram-v0)
# EnvSpec(Freeway-ram-v4)
# EnvSpec(Freeway-ramDeterministic-v0)
# EnvSpec(Freeway-ramDeterministic-v4)
# EnvSpec(Freeway-ramNoFrameskip-v0)
# EnvSpec(Freeway-ramNoFrameskip-v4)
# EnvSpec(Frostbite-v0)
# EnvSpec(Frostbite-v4)
# EnvSpec(FrostbiteDeterministic-v0)
# EnvSpec(FrostbiteDeterministic-v4)
# EnvSpec(FrostbiteNoFrameskip-v0)
# EnvSpec(FrostbiteNoFrameskip-v4)
# EnvSpec(Frostbite-ram-v0)
# EnvSpec(Frostbite-ram-v4)
# EnvSpec(Frostbite-ramDeterministic-v0)
# EnvSpec(Frostbite-ramDeterministic-v4)
# EnvSpec(Frostbite-ramNoFrameskip-v0)
# EnvSpec(Frostbite-ramNoFrameskip-v4)
# EnvSpec(Gopher-v0)
# EnvSpec(Gopher-v4)
# EnvSpec(GopherDeterministic-v0)
# EnvSpec(GopherDeterministic-v4)
# EnvSpec(GopherNoFrameskip-v0)
# EnvSpec(GopherNoFrameskip-v4)
# EnvSpec(Gopher-ram-v0)
# EnvSpec(Gopher-ram-v4)
# EnvSpec(Gopher-ramDeterministic-v0)
# EnvSpec(Gopher-ramDeterministic-v4)
# EnvSpec(Gopher-ramNoFrameskip-v0)
# EnvSpec(Gopher-ramNoFrameskip-v4)
# EnvSpec(Gravitar-v0)
# EnvSpec(Gravitar-v4)
# EnvSpec(GravitarDeterministic-v0)
# EnvSpec(GravitarDeterministic-v4)
# EnvSpec(GravitarNoFrameskip-v0)
# EnvSpec(GravitarNoFrameskip-v4)
# EnvSpec(Gravitar-ram-v0)
# EnvSpec(Gravitar-ram-v4)
# EnvSpec(Gravitar-ramDeterministic-v0)
# EnvSpec(Gravitar-ramDeterministic-v4)
# EnvSpec(Gravitar-ramNoFrameskip-v0)
# EnvSpec(Gravitar-ramNoFrameskip-v4)
# EnvSpec(Hero-v0)
# EnvSpec(Hero-v4)
# EnvSpec(HeroDeterministic-v0)
# EnvSpec(HeroDeterministic-v4)
# EnvSpec(HeroNoFrameskip-v0)
# EnvSpec(HeroNoFrameskip-v4)
# EnvSpec(Hero-ram-v0)
# EnvSpec(Hero-ram-v4)
# EnvSpec(Hero-ramDeterministic-v0)
# EnvSpec(Hero-ramDeterministic-v4)
# EnvSpec(Hero-ramNoFrameskip-v0)
# EnvSpec(Hero-ramNoFrameskip-v4)
# EnvSpec(IceHockey-v0)
# EnvSpec(IceHockey-v4)
# EnvSpec(IceHockeyDeterministic-v0)
# EnvSpec(IceHockeyDeterministic-v4)
# EnvSpec(IceHockeyNoFrameskip-v0)
# EnvSpec(IceHockeyNoFrameskip-v4)
# EnvSpec(IceHockey-ram-v0)
# EnvSpec(IceHockey-ram-v4)
# EnvSpec(IceHockey-ramDeterministic-v0)
# EnvSpec(IceHockey-ramDeterministic-v4)
# EnvSpec(IceHockey-ramNoFrameskip-v0)
# EnvSpec(IceHockey-ramNoFrameskip-v4)
# EnvSpec(Jamesbond-v0)
# EnvSpec(Jamesbond-v4)
# EnvSpec(JamesbondDeterministic-v0)
# EnvSpec(JamesbondDeterministic-v4)
# EnvSpec(JamesbondNoFrameskip-v0)
# EnvSpec(JamesbondNoFrameskip-v4)
# EnvSpec(Jamesbond-ram-v0)
# EnvSpec(Jamesbond-ram-v4)
# EnvSpec(Jamesbond-ramDeterministic-v0)
# EnvSpec(Jamesbond-ramDeterministic-v4)
# EnvSpec(Jamesbond-ramNoFrameskip-v0)
# EnvSpec(Jamesbond-ramNoFrameskip-v4)
# EnvSpec(JourneyEscape-v0)
# EnvSpec(JourneyEscape-v4)
# EnvSpec(JourneyEscapeDeterministic-v0)
# EnvSpec(JourneyEscapeDeterministic-v4)
# EnvSpec(JourneyEscapeNoFrameskip-v0)
# EnvSpec(JourneyEscapeNoFrameskip-v4)
# EnvSpec(JourneyEscape-ram-v0)
# EnvSpec(JourneyEscape-ram-v4)
# EnvSpec(JourneyEscape-ramDeterministic-v0)
# EnvSpec(JourneyEscape-ramDeterministic-v4)
# EnvSpec(JourneyEscape-ramNoFrameskip-v0)
# EnvSpec(JourneyEscape-ramNoFrameskip-v4)
# EnvSpec(Kangaroo-v0)
# EnvSpec(Kangaroo-v4)
# EnvSpec(KangarooDeterministic-v0)
# EnvSpec(KangarooDeterministic-v4)
# EnvSpec(KangarooNoFrameskip-v0)
# EnvSpec(KangarooNoFrameskip-v4)
# EnvSpec(Kangaroo-ram-v0)
# EnvSpec(Kangaroo-ram-v4)
# EnvSpec(Kangaroo-ramDeterministic-v0)
# EnvSpec(Kangaroo-ramDeterministic-v4)
# EnvSpec(Kangaroo-ramNoFrameskip-v0)
# EnvSpec(Kangaroo-ramNoFrameskip-v4)
# EnvSpec(Krull-v0)
# EnvSpec(Krull-v4)
# EnvSpec(KrullDeterministic-v0)
# EnvSpec(KrullDeterministic-v4)
# EnvSpec(KrullNoFrameskip-v0)
# EnvSpec(KrullNoFrameskip-v4)
# EnvSpec(Krull-ram-v0)
# EnvSpec(Krull-ram-v4)
# EnvSpec(Krull-ramDeterministic-v0)
# EnvSpec(Krull-ramDeterministic-v4)
# EnvSpec(Krull-ramNoFrameskip-v0)
# EnvSpec(Krull-ramNoFrameskip-v4)
# EnvSpec(KungFuMaster-v0)
# EnvSpec(KungFuMaster-v4)
# EnvSpec(KungFuMasterDeterministic-v0)
# EnvSpec(KungFuMasterDeterministic-v4)
# EnvSpec(KungFuMasterNoFrameskip-v0)
# EnvSpec(KungFuMasterNoFrameskip-v4)
# EnvSpec(KungFuMaster-ram-v0)
# EnvSpec(KungFuMaster-ram-v4)
# EnvSpec(KungFuMaster-ramDeterministic-v0)
# EnvSpec(KungFuMaster-ramDeterministic-v4)
# EnvSpec(KungFuMaster-ramNoFrameskip-v0)
# EnvSpec(KungFuMaster-ramNoFrameskip-v4)
# EnvSpec(MontezumaRevenge-v0)
# EnvSpec(MontezumaRevenge-v4)
# EnvSpec(MontezumaRevengeDeterministic-v0)
# EnvSpec(MontezumaRevengeDeterministic-v4)
# EnvSpec(MontezumaRevengeNoFrameskip-v0)
# EnvSpec(MontezumaRevengeNoFrameskip-v4)
# EnvSpec(MontezumaRevenge-ram-v0)
# EnvSpec(MontezumaRevenge-ram-v4)
# EnvSpec(MontezumaRevenge-ramDeterministic-v0)
# EnvSpec(MontezumaRevenge-ramDeterministic-v4)
# EnvSpec(MontezumaRevenge-ramNoFrameskip-v0)
# EnvSpec(MontezumaRevenge-ramNoFrameskip-v4)
# EnvSpec(MsPacman-v0)
# EnvSpec(MsPacman-v4)
# EnvSpec(MsPacmanDeterministic-v0)
# EnvSpec(MsPacmanDeterministic-v4)
# EnvSpec(MsPacmanNoFrameskip-v0)
# EnvSpec(MsPacmanNoFrameskip-v4)
# EnvSpec(MsPacman-ram-v0)
# EnvSpec(MsPacman-ram-v4)
# EnvSpec(MsPacman-ramDeterministic-v0)
# EnvSpec(MsPacman-ramDeterministic-v4)
# EnvSpec(MsPacman-ramNoFrameskip-v0)
# EnvSpec(MsPacman-ramNoFrameskip-v4)
# EnvSpec(NameThisGame-v0)
# EnvSpec(NameThisGame-v4)
# EnvSpec(NameThisGameDeterministic-v0)
# EnvSpec(NameThisGameDeterministic-v4)
# EnvSpec(NameThisGameNoFrameskip-v0)
# EnvSpec(NameThisGameNoFrameskip-v4)
# EnvSpec(NameThisGame-ram-v0)
# EnvSpec(NameThisGame-ram-v4)
# EnvSpec(NameThisGame-ramDeterministic-v0)
# EnvSpec(NameThisGame-ramDeterministic-v4)
# EnvSpec(NameThisGame-ramNoFrameskip-v0)
# EnvSpec(NameThisGame-ramNoFrameskip-v4)
# EnvSpec(Phoenix-v0)
# EnvSpec(Phoenix-v4)
# EnvSpec(PhoenixDeterministic-v0)
# EnvSpec(PhoenixDeterministic-v4)
# EnvSpec(PhoenixNoFrameskip-v0)
# EnvSpec(PhoenixNoFrameskip-v4)
# EnvSpec(Phoenix-ram-v0)
# EnvSpec(Phoenix-ram-v4)
# EnvSpec(Phoenix-ramDeterministic-v0)
# EnvSpec(Phoenix-ramDeterministic-v4)
# EnvSpec(Phoenix-ramNoFrameskip-v0)
# EnvSpec(Phoenix-ramNoFrameskip-v4)
# EnvSpec(Pitfall-v0)
# EnvSpec(Pitfall-v4)
# EnvSpec(PitfallDeterministic-v0)
# EnvSpec(PitfallDeterministic-v4)
# EnvSpec(PitfallNoFrameskip-v0)
# EnvSpec(PitfallNoFrameskip-v4)
# EnvSpec(Pitfall-ram-v0)
# EnvSpec(Pitfall-ram-v4)
# EnvSpec(Pitfall-ramDeterministic-v0)
# EnvSpec(Pitfall-ramDeterministic-v4)
# EnvSpec(Pitfall-ramNoFrameskip-v0)
# EnvSpec(Pitfall-ramNoFrameskip-v4)
# EnvSpec(Pong-v0)
# EnvSpec(Pong-v4)
# EnvSpec(PongDeterministic-v0)
# EnvSpec(PongDeterministic-v4)
# EnvSpec(PongNoFrameskip-v0)
# EnvSpec(PongNoFrameskip-v4)
# EnvSpec(Pong-ram-v0)
# EnvSpec(Pong-ram-v4)
# EnvSpec(Pong-ramDeterministic-v0)
# EnvSpec(Pong-ramDeterministic-v4)
# EnvSpec(Pong-ramNoFrameskip-v0)
# EnvSpec(Pong-ramNoFrameskip-v4)
# EnvSpec(Pooyan-v0)
# EnvSpec(Pooyan-v4)
# EnvSpec(PooyanDeterministic-v0)
# EnvSpec(PooyanDeterministic-v4)
# EnvSpec(PooyanNoFrameskip-v0)
# EnvSpec(PooyanNoFrameskip-v4)
# EnvSpec(Pooyan-ram-v0)
# EnvSpec(Pooyan-ram-v4)
# EnvSpec(Pooyan-ramDeterministic-v0)
# EnvSpec(Pooyan-ramDeterministic-v4)
# EnvSpec(Pooyan-ramNoFrameskip-v0)
# EnvSpec(Pooyan-ramNoFrameskip-v4)
# EnvSpec(PrivateEye-v0)
# EnvSpec(PrivateEye-v4)
# EnvSpec(PrivateEyeDeterministic-v0)
# EnvSpec(PrivateEyeDeterministic-v4)
# EnvSpec(PrivateEyeNoFrameskip-v0)
# EnvSpec(PrivateEyeNoFrameskip-v4)
# EnvSpec(PrivateEye-ram-v0)
# EnvSpec(PrivateEye-ram-v4)
# EnvSpec(PrivateEye-ramDeterministic-v0)
# EnvSpec(PrivateEye-ramDeterministic-v4)
# EnvSpec(PrivateEye-ramNoFrameskip-v0)
# EnvSpec(PrivateEye-ramNoFrameskip-v4)
# EnvSpec(Qbert-v0)
# EnvSpec(Qbert-v4)
# EnvSpec(QbertDeterministic-v0)
# EnvSpec(QbertDeterministic-v4)
# EnvSpec(QbertNoFrameskip-v0)
# EnvSpec(QbertNoFrameskip-v4)
# EnvSpec(Qbert-ram-v0)
# EnvSpec(Qbert-ram-v4)
# EnvSpec(Qbert-ramDeterministic-v0)
# EnvSpec(Qbert-ramDeterministic-v4)
# EnvSpec(Qbert-ramNoFrameskip-v0)
# EnvSpec(Qbert-ramNoFrameskip-v4)
# EnvSpec(Riverraid-v0)
# EnvSpec(Riverraid-v4)
# EnvSpec(RiverraidDeterministic-v0)
# EnvSpec(RiverraidDeterministic-v4)
# EnvSpec(RiverraidNoFrameskip-v0)
# EnvSpec(RiverraidNoFrameskip-v4)
# EnvSpec(Riverraid-ram-v0)
# EnvSpec(Riverraid-ram-v4)
# EnvSpec(Riverraid-ramDeterministic-v0)
# EnvSpec(Riverraid-ramDeterministic-v4)
# EnvSpec(Riverraid-ramNoFrameskip-v0)
# EnvSpec(Riverraid-ramNoFrameskip-v4)
# EnvSpec(RoadRunner-v0)
# EnvSpec(RoadRunner-v4)
# EnvSpec(RoadRunnerDeterministic-v0)
# EnvSpec(RoadRunnerDeterministic-v4)
# EnvSpec(RoadRunnerNoFrameskip-v0)
# EnvSpec(RoadRunnerNoFrameskip-v4)
# EnvSpec(RoadRunner-ram-v0)
# EnvSpec(RoadRunner-ram-v4)
# EnvSpec(RoadRunner-ramDeterministic-v0)
# EnvSpec(RoadRunner-ramDeterministic-v4)
# EnvSpec(RoadRunner-ramNoFrameskip-v0)
# EnvSpec(RoadRunner-ramNoFrameskip-v4)
# EnvSpec(Robotank-v0)
# EnvSpec(Robotank-v4)
# EnvSpec(RobotankDeterministic-v0)
# EnvSpec(RobotankDeterministic-v4)
# EnvSpec(RobotankNoFrameskip-v0)
# EnvSpec(RobotankNoFrameskip-v4)
# EnvSpec(Robotank-ram-v0)
# EnvSpec(Robotank-ram-v4)
# EnvSpec(Robotank-ramDeterministic-v0)
# EnvSpec(Robotank-ramDeterministic-v4)
# EnvSpec(Robotank-ramNoFrameskip-v0)
# EnvSpec(Robotank-ramNoFrameskip-v4)
# EnvSpec(Seaquest-v0)
# EnvSpec(Seaquest-v4)
# EnvSpec(SeaquestDeterministic-v0)
# EnvSpec(SeaquestDeterministic-v4)
# EnvSpec(SeaquestNoFrameskip-v0)
# EnvSpec(SeaquestNoFrameskip-v4)
# EnvSpec(Seaquest-ram-v0)
# EnvSpec(Seaquest-ram-v4)
# EnvSpec(Seaquest-ramDeterministic-v0)
# EnvSpec(Seaquest-ramDeterministic-v4)
# EnvSpec(Seaquest-ramNoFrameskip-v0)
# EnvSpec(Seaquest-ramNoFrameskip-v4)
# EnvSpec(Skiing-v0)
# EnvSpec(Skiing-v4)
# EnvSpec(SkiingDeterministic-v0)
# EnvSpec(SkiingDeterministic-v4)
# EnvSpec(SkiingNoFrameskip-v0)
# EnvSpec(SkiingNoFrameskip-v4)
# EnvSpec(Skiing-ram-v0)
# EnvSpec(Skiing-ram-v4)
# EnvSpec(Skiing-ramDeterministic-v0)
# EnvSpec(Skiing-ramDeterministic-v4)
# EnvSpec(Skiing-ramNoFrameskip-v0)
# EnvSpec(Skiing-ramNoFrameskip-v4)
# EnvSpec(Solaris-v0)
# EnvSpec(Solaris-v4)
# EnvSpec(SolarisDeterministic-v0)
# EnvSpec(SolarisDeterministic-v4)
# EnvSpec(SolarisNoFrameskip-v0)
# EnvSpec(SolarisNoFrameskip-v4)
# EnvSpec(Solaris-ram-v0)
# EnvSpec(Solaris-ram-v4)
# EnvSpec(Solaris-ramDeterministic-v0)
# EnvSpec(Solaris-ramDeterministic-v4)
# EnvSpec(Solaris-ramNoFrameskip-v0)
# EnvSpec(Solaris-ramNoFrameskip-v4)
# EnvSpec(SpaceInvaders-v0)
# EnvSpec(SpaceInvaders-v4)
# EnvSpec(SpaceInvadersDeterministic-v0)
# EnvSpec(SpaceInvadersDeterministic-v4)
# EnvSpec(SpaceInvadersNoFrameskip-v0)
# EnvSpec(SpaceInvadersNoFrameskip-v4)
# EnvSpec(SpaceInvaders-ram-v0)
# EnvSpec(SpaceInvaders-ram-v4)
# EnvSpec(SpaceInvaders-ramDeterministic-v0)
# EnvSpec(SpaceInvaders-ramDeterministic-v4)
# EnvSpec(SpaceInvaders-ramNoFrameskip-v0)
# EnvSpec(SpaceInvaders-ramNoFrameskip-v4)
# EnvSpec(StarGunner-v0)
# EnvSpec(StarGunner-v4)
# EnvSpec(StarGunnerDeterministic-v0)
# EnvSpec(StarGunnerDeterministic-v4)
# EnvSpec(StarGunnerNoFrameskip-v0)
# EnvSpec(StarGunnerNoFrameskip-v4)
# EnvSpec(StarGunner-ram-v0)
# EnvSpec(StarGunner-ram-v4)
# EnvSpec(StarGunner-ramDeterministic-v0)
# EnvSpec(StarGunner-ramDeterministic-v4)
# EnvSpec(StarGunner-ramNoFrameskip-v0)
# EnvSpec(StarGunner-ramNoFrameskip-v4)
# EnvSpec(Tennis-v0)
# EnvSpec(Tennis-v4)
# EnvSpec(TennisDeterministic-v0)
# EnvSpec(TennisDeterministic-v4)
# EnvSpec(TennisNoFrameskip-v0)
# EnvSpec(TennisNoFrameskip-v4)
# EnvSpec(Tennis-ram-v0)
# EnvSpec(Tennis-ram-v4)
# EnvSpec(Tennis-ramDeterministic-v0)
# EnvSpec(Tennis-ramDeterministic-v4)
# EnvSpec(Tennis-ramNoFrameskip-v0)
# EnvSpec(Tennis-ramNoFrameskip-v4)
# EnvSpec(TimePilot-v0)
# EnvSpec(TimePilot-v4)
# EnvSpec(TimePilotDeterministic-v0)
# EnvSpec(TimePilotDeterministic-v4)
# EnvSpec(TimePilotNoFrameskip-v0)
# EnvSpec(TimePilotNoFrameskip-v4)
# EnvSpec(TimePilot-ram-v0)
# EnvSpec(TimePilot-ram-v4)
# EnvSpec(TimePilot-ramDeterministic-v0)
# EnvSpec(TimePilot-ramDeterministic-v4)
# EnvSpec(TimePilot-ramNoFrameskip-v0)
# EnvSpec(TimePilot-ramNoFrameskip-v4)
# EnvSpec(Tutankham-v0)
# EnvSpec(Tutankham-v4)
# EnvSpec(TutankhamDeterministic-v0)
# EnvSpec(TutankhamDeterministic-v4)
# EnvSpec(TutankhamNoFrameskip-v0)
# EnvSpec(TutankhamNoFrameskip-v4)
# EnvSpec(Tutankham-ram-v0)
# EnvSpec(Tutankham-ram-v4)
# EnvSpec(Tutankham-ramDeterministic-v0)
# EnvSpec(Tutankham-ramDeterministic-v4)
# EnvSpec(Tutankham-ramNoFrameskip-v0)
# EnvSpec(Tutankham-ramNoFrameskip-v4)
# EnvSpec(UpNDown-v0)
# EnvSpec(UpNDown-v4)
# EnvSpec(UpNDownDeterministic-v0)
# EnvSpec(UpNDownDeterministic-v4)
# EnvSpec(UpNDownNoFrameskip-v0)
# EnvSpec(UpNDownNoFrameskip-v4)
# EnvSpec(UpNDown-ram-v0)
# EnvSpec(UpNDown-ram-v4)
# EnvSpec(UpNDown-ramDeterministic-v0)
# EnvSpec(UpNDown-ramDeterministic-v4)
# EnvSpec(UpNDown-ramNoFrameskip-v0)
# EnvSpec(UpNDown-ramNoFrameskip-v4)
# EnvSpec(Venture-v0)
# EnvSpec(Venture-v4)
# EnvSpec(VentureDeterministic-v0)
# EnvSpec(VentureDeterministic-v4)
# EnvSpec(VentureNoFrameskip-v0)
# EnvSpec(VentureNoFrameskip-v4)
# EnvSpec(Venture-ram-v0)
# EnvSpec(Venture-ram-v4)
# EnvSpec(Venture-ramDeterministic-v0)
# EnvSpec(Venture-ramDeterministic-v4)
# EnvSpec(Venture-ramNoFrameskip-v0)
# EnvSpec(Venture-ramNoFrameskip-v4)
# EnvSpec(VideoPinball-v0)
# EnvSpec(VideoPinball-v4)
# EnvSpec(VideoPinballDeterministic-v0)
# EnvSpec(VideoPinballDeterministic-v4)
# EnvSpec(VideoPinballNoFrameskip-v0)
# EnvSpec(VideoPinballNoFrameskip-v4)
# EnvSpec(VideoPinball-ram-v0)
# EnvSpec(VideoPinball-ram-v4)
# EnvSpec(VideoPinball-ramDeterministic-v0)
# EnvSpec(VideoPinball-ramDeterministic-v4)
# EnvSpec(VideoPinball-ramNoFrameskip-v0)
# EnvSpec(VideoPinball-ramNoFrameskip-v4)
# EnvSpec(WizardOfWor-v0)
# EnvSpec(WizardOfWor-v4)
# EnvSpec(WizardOfWorDeterministic-v0)
# EnvSpec(WizardOfWorDeterministic-v4)
# EnvSpec(WizardOfWorNoFrameskip-v0)
# EnvSpec(WizardOfWorNoFrameskip-v4)
# EnvSpec(WizardOfWor-ram-v0)
# EnvSpec(WizardOfWor-ram-v4)
# EnvSpec(WizardOfWor-ramDeterministic-v0)
# EnvSpec(WizardOfWor-ramDeterministic-v4)
# EnvSpec(WizardOfWor-ramNoFrameskip-v0)
# EnvSpec(WizardOfWor-ramNoFrameskip-v4)
# EnvSpec(YarsRevenge-v0)
# EnvSpec(YarsRevenge-v4)
# EnvSpec(YarsRevengeDeterministic-v0)
# EnvSpec(YarsRevengeDeterministic-v4)
# EnvSpec(YarsRevengeNoFrameskip-v0)
# EnvSpec(YarsRevengeNoFrameskip-v4)
# EnvSpec(YarsRevenge-ram-v0)
# EnvSpec(YarsRevenge-ram-v4)
# EnvSpec(YarsRevenge-ramDeterministic-v0)
# EnvSpec(YarsRevenge-ramDeterministic-v4)
# EnvSpec(YarsRevenge-ramNoFrameskip-v0)
# EnvSpec(YarsRevenge-ramNoFrameskip-v4)
# EnvSpec(Zaxxon-v0)
# EnvSpec(Zaxxon-v4)
# EnvSpec(ZaxxonDeterministic-v0)
# EnvSpec(ZaxxonDeterministic-v4)
# EnvSpec(ZaxxonNoFrameskip-v0)
# EnvSpec(ZaxxonNoFrameskip-v4)
# EnvSpec(Zaxxon-ram-v0)
# EnvSpec(Zaxxon-ram-v4)
# EnvSpec(Zaxxon-ramDeterministic-v0)
# EnvSpec(Zaxxon-ramDeterministic-v4)
# EnvSpec(Zaxxon-ramNoFrameskip-v0)
# EnvSpec(Zaxxon-ramNoFrameskip-v4)
# EnvSpec(CubeCrash-v0)
# EnvSpec(CubeCrashSparse-v0)
# EnvSpec(CubeCrashScreenBecomesBlack-v0)
# EnvSpec(MemorizeDigits-v0)

# %%
# !pip install "gym[atari]"
env=gym.make('MsPacman-v0')
# Out:
# Requirement already satisfied: gym[atari] in c:\users\13154\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied: requests>=2.0 in c:\users\13154\anaconda3\lib\site-packages (from gym[atari]) (2.20.1)
# Requirement already satisfied: pyglet>=1.2.0 in c:\users\13154\anaconda3\lib\site-packages (from gym[atari]) (1.3.2)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\13154\anaconda3\lib\site-packages (from gym[atari]) (1.15.4)
# Requirement already satisfied: six in c:\users\13154\anaconda3\lib\site-packages (from gym[atari]) (1.11.0)
# Requirement already satisfied: scipy in c:\users\13154\anaconda3\lib\site-packages (from gym[atari]) (1.1.0)
# Requirement already satisfied: Pillow; extra == "atari" in c:\users\13154\anaconda3\lib\site-packages (from gym[atari]) (5.3.0)
# Collecting atari-py>=0.1.4; extra == "atari" (from gym[atari])
#   Using cached https://files.pythonhosted.org/packages/f2/9a/23cb3c2be84dd44cde56a56e1749b4d54edf3d4e492928f2c96b706b1379/atari-py-0.1.7.tar.gz
# Collecting PyOpenGL; extra == "atari" (from gym[atari])
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\13154\anaconda3\lib\site-packages (from requests>=2.0->gym[atari]) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\13154\anaconda3\lib\site-packages (from requests>=2.0->gym[atari]) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\13154\anaconda3\lib\site-packages (from requests>=2.0->gym[atari]) (2018.10.15)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\13154\anaconda3\lib\site-packages (from requests>=2.0->gym[atari]) (2.7)
# Requirement already satisfied: future in c:\users\13154\anaconda3\lib\site-packages (from pyglet>=1.2.0->gym[atari]) (0.17.1)
# Building wheels for collected packages: atari-py
#   Running setup.py bdist_wheel for atari-py: started
#   Running setup.py bdist_wheel for atari-py: finished with status 'error'
#   Complete output from command C:\Users\13154\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\13154\\AppData\\Local\\Temp\\pip-install-kjblleqq\\atari-py\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\13154\AppData\Local\Temp\pip-wheel-k5zagj9v --python-tag cp36:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.6
#   creating build\lib.win-amd64-3.6\atari_py
#   copying atari_py\ale_python_interface.py -> build\lib.win-amd64-3.6\atari_py
#   copying atari_py\__init__.py -> build\lib.win-amd64-3.6\atari_py
#   copying atari_py\ale_c_wrapper.cpp -> build\lib.win-amd64-3.6\atari_py
#   copying atari_py\ale_c_wrapper.h -> build\lib.win-amd64-3.6\atari_py
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface
#   copying atari_py\ale_interface\CMakeLists.txt -> build\lib.win-amd64-3.6\atari_py\ale_interface
#   copying atari_py\ale_interface\Makefile -> build\lib.win-amd64-3.6\atari_py\ale_interface
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src
#   copying atari_py\ale_interface\src\ale_interface.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src
#   copying atari_py\ale_interface\src\ale_interface.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\Array.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\ColourPalette.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\ColourPalette.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\Constants.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\Constants.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\Log.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\Log.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\Palettes.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\ScreenExporter.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\ScreenExporter.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\SoundExporter.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\SoundExporter.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\SoundNull.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\SoundNull.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\SoundSDL.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\SoundSDL.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\Version.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\VideoModeList.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\display_screen.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\display_screen.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\misc_tools.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\stella.png -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   copying atari_py\ale_interface\src\common\stella.xpm -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\common
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\controllers
#   copying atari_py\ale_interface\src\controllers\ale_controller.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\controllers
#   copying atari_py\ale_interface\src\controllers\ale_controller.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\controllers
#   copying atari_py\ale_interface\src\controllers\fifo_controller.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\controllers
#   copying atari_py\ale_interface\src\controllers\fifo_controller.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\controllers
#   copying atari_py\ale_interface\src\controllers\rlglue_controller.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\controllers
#   copying atari_py\ale_interface\src\controllers\rlglue_controller.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\controllers
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\AtariVox.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\AtariVox.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Booster.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Booster.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart0840.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart0840.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart2K.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart2K.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart3E.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart3E.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart3F.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart3F.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart4A50.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart4A50.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart4K.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Cart4K.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartAR.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartAR.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartCV.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartCV.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartDPC.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartDPC.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartE0.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartE0.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartE7.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartE7.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF4.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF4.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF4SC.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF4SC.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF6.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF6.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF6SC.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF6SC.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF8.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF8.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF8SC.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartF8SC.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartFASC.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartFASC.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartFE.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartFE.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartMB.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartMB.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartMC.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartMC.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartUA.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\CartUA.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Console.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Console.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Control.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Control.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\DefProps.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Deserializer.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Deserializer.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Driving.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Driving.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Event.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Event.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\FSNode.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\FSNode.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Joystick.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Joystick.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Keyboard.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Keyboard.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\M6532.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\M6532.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\MD5.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\MD5.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\MediaSrc.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\MediaSrc.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\OSystem.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\OSystem.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Paddles.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Paddles.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Props.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Props.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\PropsSet.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\PropsSet.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Random.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Random.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Serializer.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Serializer.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Settings.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Settings.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Sound.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\SpeakJet.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\SpeakJet.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Switches.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\Switches.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\TIA.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\TIA.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\TIASnd.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\TIASnd.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502
#   copying atari_py\ale_interface\src\emucore\m6502\Copyright.txt -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502
#   copying atari_py\ale_interface\src\emucore\m6502\License.txt -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\Device.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\Device.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502.m4 -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502Hi.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502Hi.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502Hi.ins -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502Hi.m4 -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502Low.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502Low.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502Low.ins -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\M6502Low.m4 -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\NullDev.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\NullDev.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\System.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\System.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src\bspf
#   copying atari_py\ale_interface\src\emucore\m6502\src\bspf\Copyright.txt -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src\bspf
#   copying atari_py\ale_interface\src\emucore\m6502\src\bspf\License.txt -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src\bspf
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src\bspf\src
#   copying atari_py\ale_interface\src\emucore\m6502\src\bspf\src\bspf.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\m6502\src\bspf\src
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\COPYING -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\Elements.def -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\PORTING -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\config.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\darray.c -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\darray.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\elements.c -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\holmes.c -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\kmap -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\opsynth.c -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\phfeat.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\phones.c -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\phones.def -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\phones.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\phtoelm.c -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\phtoelm.def -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\phtoelm.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\rsynth.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\trie.c -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\trie.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\rsynth\useconfig.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore\rsynth
#   copying atari_py\ale_interface\src\emucore\stella.pro -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\unzip.c -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   copying atari_py\ale_interface\src\emucore\unzip.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\emucore
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\environment
#   copying atari_py\ale_interface\src\environment\ale_ram.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\environment
#   copying atari_py\ale_interface\src\environment\ale_screen.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\environment
#   copying atari_py\ale_interface\src\environment\ale_state.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\environment
#   copying atari_py\ale_interface\src\environment\ale_state.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\environment
#   copying atari_py\ale_interface\src\environment\phosphor_blend.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\environment
#   copying atari_py\ale_interface\src\environment\phosphor_blend.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\environment
#   copying atari_py\ale_interface\src\environment\stella_environment.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\environment
#   copying atari_py\ale_interface\src\environment\stella_environment.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\environment
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\external
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\external\TinyMT
#   copying atari_py\ale_interface\src\external\TinyMT\LICENSE.txt -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\external\TinyMT
#   copying atari_py\ale_interface\src\external\TinyMT\tinymt32.c -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\external\TinyMT
#   copying atari_py\ale_interface\src\external\TinyMT\tinymt32.h -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\external\TinyMT
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\games
#   copying atari_py\ale_interface\src\games\RomSettings.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games
#   copying atari_py\ale_interface\src\games\RomSettings.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games
#   copying atari_py\ale_interface\src\games\RomUtils.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games
#   copying atari_py\ale_interface\src\games\RomUtils.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games
#   copying atari_py\ale_interface\src\games\Roms.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games
#   copying atari_py\ale_interface\src\games\Roms.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Adventure.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Adventure.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\AirRaid.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\AirRaid.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Alien.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Alien.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Amidar.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Amidar.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Assault.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Assault.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Asterix.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Asterix.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Asteroids.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Asteroids.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Atlantis.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Atlantis.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\BankHeist.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\BankHeist.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\BattleZone.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\BattleZone.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\BeamRider.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\BeamRider.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Berzerk.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Berzerk.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Bowling.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Bowling.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Boxing.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Boxing.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Breakout.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Breakout.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Carnival.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Carnival.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Centipede.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Centipede.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\ChopperCommand.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\ChopperCommand.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\CrazyClimber.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\CrazyClimber.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Defender.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Defender.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\DemonAttack.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\DemonAttack.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\DoubleDunk.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\DoubleDunk.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\ElevatorAction.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\ElevatorAction.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Enduro.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Enduro.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\FishingDerby.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\FishingDerby.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Freeway.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Freeway.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Frostbite.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Frostbite.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Gopher.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Gopher.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Gravitar.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Gravitar.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Hero.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Hero.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\IceHockey.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\IceHockey.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\JamesBond.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\JamesBond.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\JourneyEscape.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\JourneyEscape.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Kaboom.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Kaboom.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Kangaroo.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Kangaroo.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Krull.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Krull.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\KungFuMaster.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\KungFuMaster.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\MontezumaRevenge.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\MontezumaRevenge.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\MsPacman.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\MsPacman.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\NameThisGame.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\NameThisGame.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Phoenix.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Phoenix.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Pitfall.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Pitfall.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Pong.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Pong.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Pooyan.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Pooyan.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\PrivateEye.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\PrivateEye.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\QBert.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\QBert.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\RiverRaid.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\RiverRaid.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\RoadRunner.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\RoadRunner.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\RoboTank.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\RoboTank.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Seaquest.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Seaquest.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Skiing.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Skiing.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Solaris.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Solaris.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\SpaceInvaders.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\SpaceInvaders.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\StarGunner.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\StarGunner.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Tennis.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Tennis.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\TimePilot.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\TimePilot.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Tutankham.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Tutankham.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\UpNDown.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\UpNDown.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Venture.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Venture.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\VideoPinball.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\VideoPinball.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\WizardOfWor.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\WizardOfWor.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\YarsRevenge.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\YarsRevenge.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Zaxxon.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\games\supported\Zaxxon.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#   copying atari_py\ale_interface\src\main.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src
#   creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\FSNodePOSIX.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\FSNodeWin32.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\OSystemUNIX.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\OSystemUNIX.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\OSystemWin32.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\OSystemWin32.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\SettingsUNIX.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\SettingsUNIX.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\SettingsWin32.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\ale_interface\src\os_dependent\SettingsWin32.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#   copying atari_py\atari_ntsc_rgb_palette.h -> build\lib.win-amd64-3.6\atari_py
#   creating build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\adventure.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\air_raid.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\alien.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\amidar.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\assault.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\asterix.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\asteroids.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\atlantis.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\bank_heist.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\battle_zone.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\beam_rider.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\berzerk.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\bowling.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\boxing.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\breakout.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\carnival.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#   copying atari_py\atari_roms\centipede.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
# ...
#     copying atari_py\ale_interface\src\games\supported\QBert.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\RiverRaid.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\RiverRaid.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\RoadRunner.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\RoadRunner.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\RoboTank.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\RoboTank.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Seaquest.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Seaquest.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Skiing.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Skiing.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Solaris.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Solaris.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\SpaceInvaders.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\SpaceInvaders.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\StarGunner.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\StarGunner.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Tennis.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Tennis.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\TimePilot.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\TimePilot.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Tutankham.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Tutankham.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\UpNDown.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\UpNDown.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Venture.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Venture.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\VideoPinball.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\VideoPinball.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\WizardOfWor.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\WizardOfWor.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\YarsRevenge.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\YarsRevenge.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Zaxxon.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\games\supported\Zaxxon.hpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\games\supported
#     copying atari_py\ale_interface\src\main.cpp -> build\lib.win-amd64-3.6\atari_py\ale_interface\src
#     creating build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\FSNodePOSIX.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\FSNodeWin32.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\OSystemUNIX.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\OSystemUNIX.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\OSystemWin32.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\OSystemWin32.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\SettingsUNIX.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\SettingsUNIX.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\SettingsWin32.cxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\ale_interface\src\os_dependent\SettingsWin32.hxx -> build\lib.win-amd64-3.6\atari_py\ale_interface\src\os_dependent
#     copying atari_py\atari_ntsc_rgb_palette.h -> build\lib.win-amd64-3.6\atari_py
#     creating build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\adventure.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\air_raid.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\alien.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\amidar.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\assault.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\asterix.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\asteroids.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\atlantis.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\bank_heist.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\battle_zone.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\beam_rider.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\berzerk.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\bowling.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\boxing.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\breakout.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\carnival.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\centipede.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\chopper_command.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\crazy_climber.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\defender.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\demon_attack.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\double_dunk.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\elevator_action.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\enduro.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\fishing_derby.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\freeway.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\frostbite.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\gopher.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\gravitar.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\hero.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\ice_hockey.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\jamesbond.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\journey_escape.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\kaboom.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\kangaroo.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\krull.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\kung_fu_master.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\montezuma_revenge.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\ms_pacman.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\name_this_game.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\phoenix.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\pitfall.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\pong.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\pooyan.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\private_eye.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\qbert.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\riverraid.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\road_runner.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\robotank.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\seaquest.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\skiing.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\solaris.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\space_invaders.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\star_gunner.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\tennis.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\time_pilot.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\tutankham.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\up_n_down.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\venture.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\video_pinball.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\wizard_of_wor.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\yars_revenge.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\atari_roms\zaxxon.bin -> build\lib.win-amd64-3.6\atari_py\atari_roms
#     copying atari_py\package_data.txt -> build\lib.win-amd64-3.6\atari_py
#     running build_ext
#     Unable to execute 'make build -C atari_py/ale_interface -j 7'. HINT: are you sure `make` is installed?
#     error: [WinError 2] The system cannot find the file specified
#
#     ----------------------------------------
#   Failed building wheel for atari-py
# Command "C:\Users\13154\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\13154\\AppData\\Local\\Temp\\pip-install-kjblleqq\\atari-py\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\13154\AppData\Local\Temp\pip-record-_8pet311\install-record.txt --single-version-externally-managed --compile" failed with error code 1 in C:\Users\13154\AppData\Local\Temp\pip-install-kjblleqq\atari-py\
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\gym\envs\atari\atari_env.py in <module>
#       8 try:
# ----> 9     import atari_py
#      10 except ImportError as e:
#
# ModuleNotFoundError: No module named 'atari_py'
#
# During handling of the above exception, another exception occurred:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# <ipython-input-8-93a7a6ca9c11> in <module>
#       1 get_ipython().system('pip install "gym[atari]"')
# ----> 2 env=gym.make('MsPacman-v0')
#
# ~\Anaconda3\lib\site-packages\gym\envs\registration.py in make(id, **kwargs)
#     169
#     170 def make(id, **kwargs):
# --> 171     return registry.make(id, **kwargs)
#     172
#     173 def spec(id):
#
# ~\Anaconda3\lib\site-packages\gym\envs\registration.py in make(self, id, **kwargs)
#     121             logger.info('Making new env: %s', id)
#     122         spec = self.spec(id)
# --> 123         env = spec.make(**kwargs)
#     124         # We used to have people override _reset/_step rather than
#     125         # reset/step. Set _gym_disable_underscore_compat = True on
#
# ~\Anaconda3\lib\site-packages\gym\envs\registration.py in make(self, **kwargs)
#      84             env = self._entry_point(**_kwargs)
#      85         else:
# ---> 86             cls = load(self._entry_point)
#      87             env = cls(**_kwargs)
#      88
#
# ~\Anaconda3\lib\site-packages\gym\envs\registration.py in load(name)
#      12     import pkg_resources # takes ~400ms to load, so we import it lazily
#      13     entry_point = pkg_resources.EntryPoint.parse('x={}'.format(name))
# ---> 14     result = entry_point.resolve()
#      15     return result
#      16
#
# ~\Anaconda3\lib\site-packages\pkg_resources\__init__.py in resolve(self)
#    2350         Resolve the entry point from its module and attrs.
#    2351         """
# -> 2352         module = __import__(self.module_name, fromlist=['__name__'], level=0)
#    2353         try:
#    2354             return functools.reduce(getattr, self.attrs, module)
#
# ~\Anaconda3\lib\site-packages\gym\envs\atari\__init__.py in <module>
# ----> 1 from gym.envs.atari.atari_env import AtariEnv
#
# ~\Anaconda3\lib\site-packages\gym\envs\atari\atari_env.py in <module>
#       9     import atari_py
#      10 except ImportError as e:
# ---> 11     raise error.DependencyNotInstalled("{}. (HINT: you can install Atari dependencies by running 'pip install gym[atari]'.)".format(e))
#      12
#      13 def to_ram(ale):
#
# DependencyNotInstalled: No module named 'atari_py'. (HINT: you can install Atari dependencies by running 'pip install gym[atari]'.)

# %%
print(env.action_space)
# Out:
# Discrete(9)

# %%
print(env.observation_space)
# Out:
# Box(210, 160, 3)

# %%
n_height = 210
n_width = 160
n_depth = 3
n_shape = [n_height,n_width,n_depth]
n_inputs = n_height * n_width * n_depth
env.frameskip = 3

# %%
import time

frame_time = 1.0 / 15  # seconds
n_episodes = 1

for i_episode in range(n_episodes):
    t=0
    score=0
    then = 0
    done = False
    env.reset()
    while not done:
        now = time.time()
        if frame_time < now - then:
            action = env.action_space.sample()
            observation, reward, done, info = env.step(action)
            score += reward
            env.render()
            then = now
            t=t+1
    print('Episode {} finished at t {} with score {}'.format(i_episode,
                                                             t,score))
# Out:
# Episode 0 finished at t 551 with score 100.0

# %%
import time
import numpy as np

frame_time = 1.0 / 15  # seconds
n_episodes = 500

scores = []
for i_episode in range(n_episodes):
    t=0
    score=0
    then = 0
    done = False
    env.reset()
    while not done:
        now = time.time()
        if frame_time < now - then:
            action = env.action_space.sample()
            observation, reward, done, info = env.step(action)
            score += reward
            env.render()
            then = now
            t=t+1
    scores.append(score)
    #print("Episode {} finished at t {} with score {}".format(i_episode,t,score))
print('Average score {}, max {}, min {}'.format(np.mean(scores),
                                          np.max(scores),
                                          np.min(scores)
                                         ))
# Out:
# Average 219.46, max 1070.0, min 70.0

# %%
tf.reset_default_graph()
keras.backend.clear_session()

# %%
def policy_q_nn(obs, env):
    # Exploration strategy - Select a random action
    if np.random.random() < explore_rate:
        action = env.action_space.sample()
    # Exploitation strategy - Select the action with the highest q
    else:
        action = np.argmax(q_nn.predict(np.array([obs])))
    return action

def episode(env, policy, r_max=0, t_max=0):

    # create the empty list to contain game memory
    #memory = deque(maxlen=1000)
    
    # observe initial state
    obs = env.reset()
    state_prev = obs
    #state_prev = np.ravel(obs) # replaced with keras reshape[-1]
    
    # initialize the variables
    episode_reward = 0
    done = False
    t = 0
    
    while not done:
        
        action = policy(state_prev, env)
        obs, reward, done, info = env.step(action)
        state_next = obs
        #state_next = np.ravel(obs) # replaced with keras reshape[-1]
        
                                             
        # add the state_prev, action, reward, state_new, done to memory
        memory.append([state_prev,action,reward,state_next,done])
                           
        
        # Generate and update the q_values with 
        # maximum future rewards using bellman function:
        states = np.array([x[0] for x in memory])
        states_next = np.array([np.zeros(n_shape) if x[4] else x[3] for x in memory])
        
        q_values = q_nn.predict(states)
        q_values_next = q_nn.predict(states_next)
        
        for i in range(len(memory)):
            state_prev,action,reward,state_next,done = memory[i]
            if done:
                q_values[i,action] = reward
            else:
                best_q = np.amax(q_values_next[i])
                bellman_q = reward + discount_rate * best_q
                q_values[i,action] = bellman_q
        
        # train the q_nn with states and q_values, same as updating the q_table
        q_nn.fit(states,q_values,epochs=1,batch_size=50,verbose=0)
    
        state_prev = state_next
        
        episode_reward += reward
        if r_max > 0 and episode_reward > r_max:
            break
        t+=1
        if t_max > 0 and t == t_max:
            break
    return episode_reward

# experiment collect observations and rewards for each episode
def experiment(env, policy, n_episodes,r_max=0, t_max=0):
    
    rewards=np.empty(shape=[n_episodes])
    for i in range(n_episodes):
        val = episode(env, policy, r_max, t_max)
        #print('episode:{}, reward {}'.format(i,val))
        rewards[i]=val
            
    print('Policy:{}, Min reward:{}, Max reward:{}, Average reward:{}'
        .format(policy.__name__,
              np.min(rewards),
              np.max(rewards),
              np.mean(rewards)))

# %%
from collections import deque 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# build the Q-Network
model = Sequential()
model.add(Flatten(input_shape = n_shape))
model.add(Dense(512, activation='relu',name='hidden1'))
model.add(Dense(9, activation='softmax', name='output'))
model.compile(loss='categorical_crossentropy',optimizer='adam')
model.summary()
q_nn = model
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 100800)            0
# _________________________________________________________________
# hidden1 (Dense)              (None, 8)                 806408
# _________________________________________________________________
# output (Dense)               (None, 9)                 81
# =================================================================
# Total params: 806,489
# Trainable params: 806,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Hyperparameters

discount_rate = 0.9
explore_rate = 0.2
n_episodes = 1

# create the empty list to contain game memory
memory = deque(maxlen=1000)

experiment(env, policy_q_nn, n_episodes)
# Out:
# Policy:policy_q_nn, Min reward:490.0, Max reward:490.0, Average reward:490.0

# %%
# Hyperparameters

discount_rate = 0.9
explore_rate = 0.2
n_episodes = 100

# create the empty list to contain game memory
memory = deque(maxlen=1000)

experiment(env, policy_q_nn, n_episodes)
# Out:
# Policy:policy_q_nn, Min reward:70.0, Max reward:580.0, Average reward:270.5

# %%
from collections import deque 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# build the CNN Q-Network
model = Sequential()
model.add(Conv2D(16, kernel_size=(5, 5), 
                 strides=(1, 1),
                 activation='relu',
                 input_shape=n_shape))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu',name='hidden1'))
model.add(Dense(9, activation='softmax', name='output'))
model.compile(loss='categorical_crossentropy',optimizer='adam')
model.summary()
q_nn = model
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 206, 156, 16)      1216
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 103, 78, 16)       0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 128544)            0
# _________________________________________________________________
# hidden1 (Dense)              (None, 512)               65815040
# _________________________________________________________________
# output (Dense)               (None, 9)                 4617
# =================================================================
# Total params: 65,820,873
# Trainable params: 65,820,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Hyperparameters

discount_rate = 0.9
explore_rate = 0.2
n_episodes = 100

# create the empty list to contain game memory
memory = deque(maxlen=1000)

experiment(env, policy_q_nn, n_episodes)

# %%
env.close()
